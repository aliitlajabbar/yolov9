# %% [markdown]
# <a href="https://colab.research.google.com/github/aliitlajabbar/yolov9/blob/main/yolov8_website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install open-cv
# %pip install ultralytics
# Out:
# ERROR: Could not find a version that satisfies the requirement open-cv (from versions: none)
# ERROR: No matching distribution found for open-cv
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.9/777.9 kB 9.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...

# %%
import cv2
from  ultralytics import YOLO

# %%
model=YOLO('yolov8n-seg.pt')
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 62.2MB/s]

# %% [markdown]
# # open the video

# %%
video_path ="/content/test.mp4"
cap=cv2.VideoCapture()

# %%
import cv2
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from IPython.display import clear_output, display
import IPython.display as ipd

# Load the YOLO model
model = YOLO('yolov8n.pt')  # Replace with the correct YOLO model path

# Specify the video file path
video_file ='/content/video_2024-05-25_02-58-55.mp4'

# Open the video file
cap = cv2.VideoCapture(video_file)

if not cap.isOpened():
    print("Error: Could not open video file.")
else:
    print("Video file opened successfully.")


while cap.isOpened():
    success, frame = cap.read()
    if success:
        # Run YOLO on the frame
        results = model(frame)

        # Visualization
        annotate_frame = results[0].plot()

        # Display the annotated frame
        clear_output(wait=True)
        cv2_imshow(annotate_frame)

        # Display the frame count for debugging
        print(f"Displaying frame {frame_count}")

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        print("No more frames to read or error reading frame.")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x360>
# Displaying frame 10923

# %%
import os

# List the files in the content directory to check if the video file exists
os.listdir('/content')
# Out:
# ['.config',
#  'yolov8n-seg.pt',
#  'test.mp4',
#  'yolov8n.pt',
#  '.ipynb_checkpoints',
#  'video_2024-05-25_00-50-47.mp4',
#  'sample_data']
